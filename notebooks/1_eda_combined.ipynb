# %% [markdown]
# ## First EDA for the capstone project

# %% [markdown]
# ### Starting to initialize the packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

# %%
c1 = '#c0791b'
c2 = '#1b786e'
c3 = '#599191'
c4 = '#5f5f5f'
c5 = '#202112'

# %%
df = pd.read_csv("../data/chatgpt_short_clean_combined_en.csv", 
                 parse_dates=["at", "repliedAt"])

# %% [markdown]
# ### Get an overview of the data

# %%
df[df.Source == "Apple"]
# Out:
#       Unnamed: 0         at  score                userName  \
# 0              0 2023-09-12      5              Tj77883344
# 1              1 2023-09-10      4           PDXJavaJunkie
# 2              2 2023-07-11      4    Tinny tower addicted
# 3              3 2023-05-27      4                Would Po
# 4              4 2023-09-20      5  MORE FREE PAINTINGS!!!
# ...          ...        ...    ...                     ...
# 6573        8606 2023-05-30      5          FutureCannabis
# 6574        8608 2023-05-30      2              kagan eker
# 6575        8611 2023-05-30      4          yorumerboi9000
# 6576        8618 2023-10-09      5                   苦闷搬砖人
# 6577        8619 2023-09-19      5                  Fonçik
#
#                                                 content Source reviewId  \
# 0     love it been using it since last years very mu...  Apple      NaN
# 1     much more accessible for blind users than the ...  Apple      NaN
# ...

# %%
df.info()
# confirm there are no objects where a float or int would be expected
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27922 entries, 0 to 27921
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         27922 non-null  int64
#  1   at                 27922 non-null  datetime64[ns]
#  2   score              27922 non-null  int64
#  3   userName           27921 non-null  object
#  4   content            27922 non-null  object
#  5   Source             27922 non-null  object
#  6   reviewId           21344 non-null  object
#  7   thumbsUpCount      21344 non-null  float64
#  8   replyContent       388 non-null    object
#  9   repliedAt          388 non-null    datetime64[ns]
#  10  appVersion         18092 non-null  object
#  11  reply              27922 non-null  int64
#  12  Reviews            27922 non-null  int64
#  13  at_ymd             27922 non-null  object
#  14  at_q               27922 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0                             at         score  \
# count  27922.000000                          27922  27922.000000
# mean    9708.754889  2023-08-25 02:45:20.435499008      4.259759
# min        0.000000            2023-05-18 00:00:00      1.000000
# 25%     3500.250000            2023-07-27 00:00:00      4.000000
# 50%     7676.500000            2023-08-29 00:00:00      5.000000
# 75%    15010.750000            2023-09-26 00:00:00      5.000000
# max    30923.000000            2023-11-04 00:00:00      5.000000
# std     7497.174489                            NaN      1.331124
#
#        thumbsUpCount                      repliedAt         reply  Reviews  \
# count   21344.000000                            388  27922.000000  27922.0
# mean        1.211019  2023-08-15 02:32:32.868556800      0.013896      1.0
# min         0.000000            2023-07-28 22:27:37      0.000000      1.0
# 25%         0.000000     2023-08-09 22:12:19.500000      0.000000      1.0
# ...

# %%
# display number of missing values per column
df.isna().sum()
# Out:
# Unnamed: 0               0
# at                       0
# score                    0
# userName                 1
# content                  0
# Source                   0
# reviewId              6578
# thumbsUpCount         6578
# replyContent         27534
# repliedAt            27534
# appVersion            9830
# reply                    0
# Reviews                  0
# at_ymd                   0
# at_q                     0
# at_ym                    0
# at_m                     0
# at_wd                    0
# at_w                     0
# score_cat                0
# detected_language        0
# dtype: int64

# %%
for var in ['Source', 'score', 'appVersion']:
    list=[]
    for i in range(1,6,1):
        x = df[var].unique()[i-1] if df[var].nunique() >= i else ''
        list.append(x)
    fig = px.histogram(df.sort_values(var), 
        x=var,
        title="Number of Reviews by " + var.capitalize(),
        labels={'count': 'Reviews'},
        text_auto=True,
        template='ggplot2',
        hover_data={"at_ym": "|%B %d, %Y"},
        color=var,
        color_discrete_map={
            list[0]: c1, 
            list[1]: c2, 
            list[2]: c3, 
            list[3]: c4,     
            list[4]: c5
            })
    fig.update_traces(textposition='auto')
    fig.update_layout(legend_title_text=var.capitalize())
    fig.update_xaxes(
        dtick="M1",
        tickformat="%B\n%Y")
    fig.update_layout(
       yaxis_title="Reviews")
    fig.show()

# %%
for var in ['Source', 'score', 'appVersion']:
    df_chart = df.groupby([var]).size().reset_index(name='Reviews') 
    df_chart['Reviews (%)'] = df_chart['Reviews'].transform(lambda x: x / x.sum() * 100)
    list=[]
    for i in range(1,6,1):
        x = df[var].unique()[i-1] if df[var].nunique() >= i else ''
        list.append(x)
    fig = px.histogram(df_chart.sort_values(var), 
        y='Reviews (%)', 
        x=var,
        title="Proportion of Reviews by " + var.capitalize(),
        labels={'count': 'Reviews'},
        text_auto="2.1f",
        template='ggplot2',
        color=var,
        color_discrete_map={
            list[0]: c1, 
            list[1]: c2, 
            list[2]: c3, 
            list[3]: c4,     
            list[4]: c5
            })
    fig.update_traces(
        textposition='auto')
    fig.update_layout(legend_title_text=var.capitalize())
    fig.update_xaxes(
        dtick="M1",
        tickformat="%B\n%Y")
    fig.update_layout(
       yaxis_title="Reviews")
    fig.show()

# %%
# Filtered for Google

for var in ['score', 'appVersion', 'reply']:
    df_chart = df[df.Source == 'Google'].groupby(['at',var]).size().reset_index(name='Reviews')
    list=[]
    for i in range(1,6,1):
        x = df[var].unique()[i-1] if df[var].nunique() >= i else ''
        list.append(x)
    fig = px.line(df_chart, 
        y='Reviews', 
        x='at',
        title="Daily Number of Reviews by " + var.capitalize(),
        labels={'at': 'Review Date'},
        template='ggplot2',
        hover_data={"at": "|%B %d, %Y"},
        color=var,
        color_discrete_map={
            list[0]: c1, 
            list[1]: c2, 
            list[2]: c3, 
            list[3]: c4,     
            list[4]: c5
            })
    fig.update_layout(legend_title_text=var.capitalize())
    fig.update_xaxes(
        dtick="M1",
        tickformat="%d.%B\n%Y")
    fig.show()

# %%
for var in ['score', 'reply']:
    df_chart = df[df.Source == 'Google'].groupby(['at',var]).size().reset_index(name='Reviews') 
    df_chart['Reviews (%)'] = df_chart.groupby('at')['Reviews'].transform(lambda x: x / x.sum() * 100)
    list=[]
    for i in range(1,6,1):
        x = df[var].unique()[i-1] if df[var].nunique() >= i else ''
        list.append(x)
    fig = px.line(df_chart, 
        y='Reviews (%)', 
        x='at',
        title="Proportion of Daily Reviews by " + var.capitalize(),
        labels={'at': 'Review Date'},
        template='ggplot2',
        hover_data={"at": "|%B %d, %Y"},
        color=var,
        color_discrete_map={
            list[0]: c1, 
            list[1]: c2, 
            list[2]: c3, 
            list[3]: c4,     
            list[4]: c5
            })
    fig.update_layout(legend_title_text=var.capitalize())
    fig.update_xaxes(
        dtick="M1",
        tickformat="%d.%B\n%Y")
    fig.show()

# %%
for var in ['score']:
    for s in ['Apple', 'Google']:
        df_chart = df[df.Source == s].groupby(['at_ym',var]).size().reset_index(name='Reviews') 
        df_chart['Reviews (%)'] = df_chart.groupby('at_ym')['Reviews'].transform(lambda x: x / x.sum() * 100)
        max_cat = df_chart[var].iloc[np.argmax(df_chart['Reviews (%)'])]
        print(max_cat)
        #df_chart['labels'] = np.where(df_chart[var]==max_cat,df_chart['Reviews (%)'], "")
        list=[]
        for i in range(1,6,1):
            x = df[var].unique()[i-1] if df[var].nunique() >= i else ''
            list.append(x)
        fig = px.line(df_chart, 
            y='Reviews (%)', 
            x='at_ym',
            text = np.where(df_chart[var]==max_cat,df_chart['Reviews (%)'], " "),
            title="Proportion of Monthly " + s + " Reviews by " + var.capitalize(),
            labels={'at_ym': 'Review Month'},
            template='ggplot2',
            hover_data={"at_ym": "|%B %d, %Y"},
            color=var,
            color_discrete_map={
                list[0]: c1, 
                list[1]: c2, 
                list[2]: c3, 
                list[3]: c4,     
                list[4]: c5
                })
        fig.update_traces(
            textposition='bottom center',
            texttemplate= "%{text:2.1f}%",
            selector = ({'name':str(max_cat)}))
        fig.update_layout(
            legend_title_text=var.capitalize(),
            autosize=False,
            width=700,
            height=400,
            font=dict(
                #family="Courier New, monospace",
                size=14,  # Set the font size here
                #color="RebeccaPurple"
            )
            )
        fig.update_xaxes(
            dtick="M1",
            tickformat="%B\n%Y")
        fig.show()
# Out:
# 5
# 5

# %%
for var in ['Source', 'appVersion', 'reply']:
    df_chart = df.groupby(['at_ym',var]).size().reset_index(name='Reviews')
    list=[]
    for i in range(1,6,1):
        x = df[var].unique()[i-1] if df[var].nunique() >= i else ''
        list.append(x)
    fig = px.line(df_chart, 
        y='Reviews', 
        x='at_ym',
        title="Monthly Number of Reviews by " + var.capitalize(),
        labels={'at_ym': 'Review Month'},
        text='Reviews',
        template='ggplot2',
        hover_data={"at_ym": "|%B %d, %Y"},
        color=var,
        color_discrete_map={
            list[0]: c1, 
            list[1]: c2, 
            list[2]: c3, 
            list[3]: c4,     
            list[4]: c5
            })
    fig.update_traces(textposition='top center')
    fig.update_layout(legend_title_text=var.capitalize())
    fig.update_xaxes(
        dtick="M1",
        tickformat="%B\n%Y")
    fig.show()

# %%
df_agg = df.groupby(['Source']).agg( 
    count_review=('Reviews', np.sum),
    score_mean=('score', 'mean'),
    first_review=('at', 'min'),
    last_review=('at', 'max'),
    versions= ('appVersion', pd.Series.nunique),
    count_reply=('reply', np.sum),
    ).reset_index().T
# Out:
# /var/folders/vl/wpx53sjn0nv5cmny0jckrfjr0000gn/T/ipykernel_14824/3193792656.py:1: FutureWarning:
#
# The provided callable <function sum at 0x107c18720> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#
# /var/folders/vl/wpx53sjn0nv5cmny0jckrfjr0000gn/T/ipykernel_14824/3193792656.py:1: FutureWarning:
#
# The provided callable <function sum at 0x107c18720> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.

# %%
df_agg
# Out:
#                                 0                    1
# Source                      Apple               Google
# count_review                 6578                21344
# score_mean               4.072818             4.317373
# first_review  2023-05-18 00:00:00  2023-07-25 00:00:00
# last_review   2023-11-04 00:00:00  2023-10-22 00:00:00
# versions                        0                   19
# count_reply                     0                  388

# %%
df_agg.to_csv("../data/ChatGPT-combined_agg.csv")
